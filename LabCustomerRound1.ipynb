# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_excel('file1.xlsx')
file2 = pd.read_excel('file2.xlsx')
file3 = pd.read_excel('file3.xlsx')

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
column_names = file1.columns
column_names
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2 = file2[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
file3 = file3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
file3.head()
# Out:
#   Customer       State Gender             Education  Customer Lifetime Value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.columns = file1.columns.str.lower()
file2.columns = file2.columns.str.lower()
file3.columns = file3.columns.str.lower()

# %%
file1.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#    income  monthly premium auto number of open complaints     policy type  \
# 0       0                  1000                    1/0/00   Personal Auto
# 1       0                    94                    1/0/00   Personal Auto
# 2   48767                   108                    1/0/00   Personal Auto
# 3       0                   106                    1/0/00  Corporate Auto
# 4   36357                    68                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
file2.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
file3.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file3.columns = file1.columns

# %%
file3.head()
# Out:
#   customer          st gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
dataframe = pd.DataFrame(columns=file1.columns)

# %%
dataframe
# Out:
# Empty DataFrame
# Columns: [customer, st, gender, education, customer lifetime value, income, monthly premium auto, number of open complaints, policy type, vehicle class, total claim amount]
# Index: []

# %%
dataframe=pd.concat([dataframe,file1,file2,file3],axis=0)

# %%
dataframe.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#   income monthly premium auto number of open complaints     policy type  \
# 0      0                 1000                    1/0/00   Personal Auto
# 1      0                   94                    1/0/00   Personal Auto
# 2  48767                  108                    1/0/00   Personal Auto
# 3      0                  106                    1/0/00  Corporate Auto
# 4  36357                   68                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# ...

# %%
dataframe.shape
# Out:
# (9137, 11)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   object
#  6   monthly premium auto       9137 non-null   object
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 856.6+ KB

# %%
# categorical data : st, gender, education, policy type, vehile class
# numerical data : customer lifetime value, income, monthly premium, number of open complaints, total claim ammount

# %%
dataframe2 = dataframe[['customer', 'st', 'gender', 'customer lifetime value',
       'income', 'monthly premium auto','policy type', 'vehicle class', 'total claim amount']]

# %%
dataframe2.head()
# Out:
#   customer          st gender customer lifetime value income  \
# 0  RB50392  Washington    NaN                     NaN      0
# 1  QZ44356     Arizona      F              697953.59%      0
# 2  AI49188      Nevada      F             1288743.17%  48767
# 3  WW63253  California      M              764586.18%      0
# 4  GA49547  Washington      M              536307.65%  36357
#
#   monthly premium auto     policy type  vehicle class  total claim amount
# 0                 1000   Personal Auto  Four-Door Car            2.704934
# 1                   94   Personal Auto  Four-Door Car         1131.464935
# 2                  108   Personal Auto   Two-Door Car          566.472247
# 3                  106  Corporate Auto            SUV          529.881344
# 4                   68   Personal Auto  Four-Door Car           17.269323

# %%
dataframe2=dataframe2.drop_duplicates()

# %%
dataframe2.shape
# Out:
# (9134, 9)

# %%
dataframe2[(dataframe2["income"]>0)]
# Out:
#      customer          st gender customer lifetime value income  \
# 2     AI49188      Nevada      F             1288743.17%  48767
# 4     GA49547  Washington      M              536307.65%  36357
# 5     OC83172      Oregon      F              825629.78%  62902
# 6     XZ87318      Oregon      F              538089.86%  55350
# 8     DY87989      Oregon      M             2412750.40%  14072
# ...       ...         ...    ...                     ...    ...
# 7063  TF56202  California      M                 5032.17  66367
# 7064  YM19146  California      F                  4100.4  47761
# 7065  LA72316  California      M                   23406  71941
# 7066  PK87824  California      F                 3096.51  21604
# 7068  UP19263  California      M                 7524.44  21941
#
#      monthly premium auto     policy type  vehicle class  total claim amount
# 2                     108   Personal Auto   Two-Door Car          566.472247
# ...

# %%
dataframe2["customer lifetime value"]*100
# Out:
# 0                                                     NaN
# 1       697953.59%697953.59%697953.59%697953.59%697953...
# 2       1288743.17%1288743.17%1288743.17%1288743.17%12...
# 3       764586.18%764586.18%764586.18%764586.18%764586...
# 4       536307.65%536307.65%536307.65%536307.65%536307...
#                               ...
# 7065                                           2.3406e+06
# 7066                                               309651
# 7067                                               816389
# 7068                                               752444
# 7069                                               261184
# Name: customer lifetime value, Length: 9134, dtype: object

# %%
dataframe2["customer lifetime value"] = dataframe2["customer lifetime value"]*100

# %%
dataframe2.head()
# Out:
#   customer          st gender  \
# 0  RB50392  Washington    NaN
# 1  QZ44356     Arizona      F
# 2  AI49188      Nevada      F
# 3  WW63253  California      M
# 4  GA49547  Washington      M
#
#                              customer lifetime value income  \
# 0                                                NaN      0
# 1  697953.59%697953.59%697953.59%697953.59%697953...      0
# 2  1288743.17%1288743.17%1288743.17%1288743.17%12...  48767
# 3  764586.18%764586.18%764586.18%764586.18%764586...      0
# 4  536307.65%536307.65%536307.65%536307.65%536307...  36357
#
#   monthly premium auto     policy type  vehicle class  total claim amount
# 0                 1000   Personal Auto  Four-Door Car            2.704934
# 1                   94   Personal Auto  Four-Door Car         1131.464935
# 2                  108   Personal Auto   Two-Door Car          566.472247
# 3                  106  Corporate Auto            SUV          529.881344
# ...

# %%
dataframe2["customer lifetime value"] = pd.to_numeric(dataframe2["customer lifetime value"], errors='coerce')

# %%
dataframe2
# Out:
#      customer          st gender  customer lifetime value income  \
# 0     RB50392  Washington    NaN                      NaN      0
# 1     QZ44356     Arizona      F                      NaN      0
# 2     AI49188      Nevada      F                      NaN  48767
# 3     WW63253  California      M                      NaN      0
# 4     GA49547  Washington      M                      NaN  36357
# ...       ...         ...    ...                      ...    ...
# 7065  LA72316  California      M             2.340599e+06  71941
# 7066  PK87824  California      F             3.096511e+05  21604
# 7067  TD14365  California      M             8.163890e+05      0
# 7068  UP19263  California      M             7.524442e+05  21941
# 7069  Y167826  California      M             2.611837e+05      0
#
#      monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000   Personal Auto  Four-Door Car            2.704934
# ...

# %%
dataframe2.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                      object
# monthly premium auto        object
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
dataframe2['income'] = pd.to_numeric(dataframe2['income'],errors='coerce')

# %%
dataframe2.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                       int64
# monthly premium auto        object
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
dataframe2['monthly premium auto'] = pd.to_numeric(dataframe2['monthly premium auto'],errors='coerce')

# %%
dataframe2.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                       int64
# monthly premium auto         int64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
dataframe2.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count             7.070000e+03   9134.000000           9134.000000
# mean              8.028804e+05  37824.847055            110.393146
# std               6.942419e+05  30359.232933            581.471461
# min               1.898008e+05      0.000000             61.000000
# 25%               3.981073e+05      0.000000             68.000000
# 50%               5.782096e+05  34240.000000             83.000000
# 75%               8.989996e+05  62446.500000            109.000000
# max               8.332538e+06  99981.000000          35354.000000
#
#        total claim amount
# count         9134.000000
# mean           430.480412
# std            289.617985
# min              0.099007
# 25%            266.961153
# 50%            377.505619
# 75%            546.050821
# max           2893.239678

# %%
dataframe2 = dataframe2.reset_index(drop=True)

# %%
filtered = dataframe2[(dataframe2['gender']== 'F')]

# %%
filtered
# Out:
#      customer          st gender  customer lifetime value  income  \
# 1     QZ44356     Arizona      F                      NaN       0
# 2     AI49188      Nevada      F                      NaN   48767
# 5     OC83172      Oregon      F                      NaN   62902
# 6     XZ87318      Oregon      F                      NaN   55350
# 9     BQ94931      Oregon      F                      NaN   28812
# ...       ...         ...    ...                      ...     ...
# 9121  BB10681  California      F             4.140649e+05       0
# 9122  FH43628  California      F             2.546482e+06   13663
# 9123  WZ45103  California      F             5.678050e+05       0
# 9128  YM19146  California      F             4.100399e+05   47761
# 9130  PK87824  California      F             3.096511e+05   21604
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 1                       94   Personal Auto  Four-Door Car         1131.464935
# ...

# %%
filtered = filtered.reset_index(drop=True)

# %%
filtered[['customer', 'st', 'income']][1:15]
# Out:
#    customer          st  income
# 1   AI49188      Nevada   48767
# 2   OC83172      Oregon   62902
# 3   XZ87318      Oregon   55350
# 4   BQ94931      Oregon   28812
# 5   HD95276  Washington       0
# 6   NW21079  Washington   67163
# 7   SP81997  Washington   41275
# 8   YB66933  Washington   77552
# 9   OW15518  Washington       0
# 10  SG20925  Washington   99428
# 11  FM14335  Washington   61108
# 12  HS28694  Washington   25317
# 13  LH92841  Washington   88891
# 14  AZ95587          AZ   61222

# %%
filtered.iloc[0:15,[1,2,5]]
# Out:
#             st gender  monthly premium auto
# 0      Arizona      F                    94
# 1       Nevada      F                   108
# 2       Oregon      F                    69
# 3       Oregon      F                    67
# 4       Oregon      F                    93
# 5   Washington      F                   130
# 6   Washington      F                    61
# 7   Washington      F                    96
# 8   Washington      F                    68
# 9   Washington      F                    87
# 10  Washington      F                  6464
# 11  Washington      F                    89
# 12  Washington      F                    71
# 13  Washington      F                    89
# 14          AZ      F                    89

# %%
filtered.iloc[50:101,[1,2,5]]
# Out:
#              st gender  monthly premium auto
# 50           WA      F                    96
# 51   California      F                   150
# 52       Nevada      F                   123
# 53      Arizona      F                    69
# 54   California      F                    72
# 55       Oregon      F                   116
# 56           WA      F                    78
# 57      Arizona      F                    64
# 58      Arizona      F                    81
# 59      Arizona      F                   108
# 60       Nevada      F                    70
# 61           WA      F                   106
# 62       Oregon      F                   135
# 63         Cali      F                    63
# 64       Oregon      F                    65
# 65         Cali      F                    64
# 66      Arizona      F                    68
# 67      Arizona      F                    94
# 68      Arizona      F                    72
# 69      Arizona      F                   103
# ...

# %%
filtered2 = filtered.iloc[50:101,[1,2,5]]

# %%
filtered2 = filtered2.reset_index().set_index('st')

# %%
filtered2[1:5]
# Out:
#             index gender  monthly premium auto
# st
# California     51      F                   150
# Nevada         52      F                   123
# Arizona        53      F                    69
# California     54      F                    72

# %%
# Percentage of null values in data
round(dataframe2.isna().sum()/len(dataframe2),4)*100
# Out:
# customer                    0.00
# st                          0.00
# gender                      1.34
# customer lifetime value    22.60
# income                      0.00
# monthly premium auto        0.00
# policy type                 0.00
# vehicle class               0.00
# total claim amount          0.00
# dtype: float64

# %%
#drop a column
filtered2 = filtered2.drop(['gender'], axis=1)

# %%
filtered2
# Out:
#             index  monthly premium auto
# st
# WA             50                    96
# California     51                   150
# Nevada         52                   123
# Arizona        53                    69
# California     54                    72
# Oregon         55                   116
# WA             56                    78
# Arizona        57                    64
# Arizona        58                    81
# Arizona        59                   108
# Nevada         60                    70
# WA             61                   106
# Oregon         62                   135
# Cali           63                    63
# Oregon         64                    65
# Cali           65                    64
# Arizona        66                    68
# Arizona        67                    94
# Arizona        68                    72
# Arizona        69                   103
# Nevada         70                    65
# Arizona        71                   133
# ...
