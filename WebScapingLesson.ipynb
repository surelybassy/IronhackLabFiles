# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests

# %%
# 2. url: we start with the 'second' page
url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt"

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
# 4.2. check that the html code looks like it should
#soup

# %%
iterations = range(1, 631, 50)

for i in iterations:
    start_at= str(i)
    url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=" + start_at + "&ref_=adv_nxt"
    print(url)
# Out:
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=1&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=101&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=151&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=201&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=251&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=301&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=351&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=401&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=451&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=501&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=551&ref_=adv_nxt
# https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=601&ref_=adv_nxt

# %% [markdown]
# Respectful scraping:
#
# There we have it, all the URLs we need! Before starting with the actual scraping, though, there's something we need to note when sending massive, automated requests to websites: it's rude.
#
# We just have 13 of them, which is not too many, but it's still a good practice to let a few seconds pass in between requests.
#
# Some pages don't like being scraped and will block your IP if they detect it's sending automated requests. Others might have a small server for the traffic they handle, and sending too many requests might crash the site. The sleep module will help us with that.
#
# Here's how it works, waiting 2 seconds between each iteration in a for loop:

# %%
#we need a few more tools for this one 
from random import randint
import time
time.sleep(2)

# %%
#basic use of sleep in for loop 
for i in range(5):
    print(i)
    time.sleep(2)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#more human use of sleep 

for i in range(5):
    print(i)
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " seconds.")
    time.sleep(wait_time)
# Out:
# 0
# I will sleep for 3 seconds.
# 1
# I will sleep for 2 seconds.
# 2
# I will sleep for 3 seconds.
# 3
# I will sleep for 2 seconds.
# 4
# I will sleep for 4 seconds.

# %% [markdown]
# to make this more interactive
# - you can split the below scripts out into separate cells and run them yourself or re-write them in your own python style

# %%
#Assembling the script to send and store multiple requests

pages = []

for i in iterations:
    # assemble the url:
    start_at= str(i)
    url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=" + start_at + "&ref_=adv_nxt"

    # download html with a get request:
    response = requests.get(url)

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))

    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    time.sleep(wait_time)
# Out:
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.

# %%
# print the object pages after running the code above, you'll just see the response code messages, but the html code is still accessible and you can parse it the same way we've always done:

#BeautifulSoup(pages[0].content, "html.parser")

# %%
# Parse just the first page, for testing purposes
soup = BeautifulSoup(pages[0].content, "html.parser")

# Paste the Selector from the first movie title copied from Chrome Dev Tools
soup.select("#main > div > div.lister.list.detail.sub-list > div > div:nth-child(1) > div.lister-item-content > h3 > a")

# Trim the selection: now it grabs all the titles
title_list = soup.select("div.lister-item-content > h3 > a")

# %%
title_list
# Out:
# [<a href="/title/tt0099785/">Kevin - Allein zu Haus</a>,
#  <a href="/title/tt0099685/">GoodFellas - Drei Jahrzehnte in der Mafia</a>,
#  <a href="/title/tt0099674/">Der Pate 3</a>,
#  <a href="/title/tt0102926/">Das Schweigen der Lämmer</a>,
#  <a href="/title/tt0100802/">Total Recall - Die totale Erinnerung</a>,
#  <a href="/title/tt0104952/">Mein Vetter Winnie</a>,
#  <a href="/title/tt0101507/">Boyz n the Hood - Jungs im Viertel</a>,
#  <a href="/title/tt0103064/">Terminator 2: Tag der Abrechnung</a>,
#  <a href="/title/tt0105323/">Der Duft der Frauen</a>,
#  <a href="/title/tt0104691/">Der letzte Mohikaner</a>,
#  <a href="/title/tt0099487/">Edward mit den Scherenhänden</a>,
#  <a href="/title/tt0099810/">Jagd auf Roter Oktober</a>,
#  <a href="/title/tt0099348/">Der mit dem Wolf tanzt</a>,
#  <a href="/title/tt0105236/">Reservoir Dogs - Wilde Hunde</a>,
#  <a href="/title/tt0104257/">Eine Frage der Ehre</a>,
#  <a href="/title/tt0105695/">Erbarmungslos</a>,
#  <a href="/title/tt0102138/">JFK: Tatort Dallas</a>,
#  <a href="/title/tt0104940/">Die Muppets Weihnachtsgeschichte</a>,
#  <a href="/title/tt0100157/">Misery</a>,
#  <a href="/title/tt0101414/">Die Schöne und das Biest</a>,
#  <a href="/title/tt0103639/">Aladdin</a>,
#  <a href="/title/tt0101921/">Grüne Tomaten</a>,
#  <a href="/title/tt0103074/">Thelma &amp; Louise</a>,
#  <a href="/title/tt0101889/">König der Fischer</a>,
#  <a href="/title/tt0099871/">Jacob's Ladder - In der Gewalt des Jenseits</a>,
#  <a href="/title/tt0106308/">Armee der Finsternis</a>,
#  <a href="/title/tt0100150/">Miller's Crossing</a>,
#  <a href="/title/tt0099040/">Ein Engel an meiner Tafel</a>,
#  <a href="/title/tt0099077/">Zeit des Erwachens</a>,
#  <a href="/title/tt0104348/">Glengarry Glen Ross</a>,
#  <a href="/title/tt0101410/">Barton Fink</a>,
#  <a href="/title/tt0104797/">Malcolm X</a>,
#  <a href="/title/tt0103939/">Chaplin - Das Leben der unsterblichen Filmlegende</a>,
#  <a href="/title/tt0101605/">Die Commitments</a>,
#  <a href="/title/tt0103873/">Braindead</a>,
#  <a href="/title/tt0105151/">The Player</a>,
#  <a href="/title/tt0105046/">Von Mäusen und Menschen</a>,
#  <a href="/title/tt0101765/">Die zwei Leben der Veronika</a>,
#  <a href="/title/tt0102536/">Night on Earth</a>,
#  <a href="/title/tt0101700/">Delicatessen</a>,
#  <a href="/title/tt0104652/">Porco Rosso</a>,
#  <a href="/title/tt0101891/">The Five Heartbeats</a>,
#  <a href="/title/tt0101428/">Die schöne Querulantin</a>,
#  <a href="/title/tt0103905/">Mann beißt Hund</a>,
#  <a href="/title/tt0101258/">Days of Being Wild</a>,
#  <a href="/title/tt0101985/">Ein Sommer zum Verlieben</a>,
#  <a href="/title/tt0102587/">Tränen der Erinnerung</a>,
#  <a href="/title/tt0101640/">Rote Laterne</a>,
#  <a href="/title/tt0100998/">Akira Kurosawa's Träume</a>,
#  <a href="/title/tt0104684/">Hard Boiled</a>]

# %%
titles = []
for title in title_list:
    print(title.text)
    
titles_set = {}
titles_set = titles
titles_set
# Out:
# Kevin - Allein zu HausKevin - Allein zu HausKevin - Allein zu HausKevin - Allein zu Haus
# GoodFellas - Drei Jahrzehnte in der MafiaGoodFellas - Drei Jahrzehnte in der MafiaGoodFellas - Drei Jahrzehnte in der MafiaGoodFellas - Drei Jahrzehnte in der Mafia
# Der Pate 3Der Pate 3Der Pate 3Der Pate 3
# Das Schweigen der LämmerDas Schweigen der LämmerDas Schweigen der LämmerDas Schweigen der Lämmer
# Total Recall - Die totale ErinnerungTotal Recall - Die totale ErinnerungTotal Recall - Die totale ErinnerungTotal Recall - Die totale Erinnerung
# Mein Vetter WinnieMein Vetter WinnieMein Vetter WinnieMein Vetter Winnie
# Boyz n the Hood - Jungs im ViertelBoyz n the Hood - Jungs im ViertelBoyz n the Hood - Jungs im ViertelBoyz n the Hood - Jungs im Viertel
# Terminator 2: Tag der AbrechnungTerminator 2: Tag der AbrechnungTerminator 2: Tag der AbrechnungTerminator 2: Tag der Abrechnung
# Der Duft der FrauenDer Duft der FrauenDer Duft der FrauenDer Duft der Frauen
# Der letzte MohikanerDer letzte MohikanerDer letzte MohikanerDer letzte Mohikaner
# Edward mit den ScherenhändenEdward mit den ScherenhändenEdward mit den ScherenhändenEdward mit den Scherenhänden
# Jagd auf Roter OktoberJagd auf Roter OktoberJagd auf Roter OktoberJagd auf Roter Oktober
# Der mit dem Wolf tanztDer mit dem Wolf tanztDer mit dem Wolf tanztDer mit dem Wolf tanzt
# Reservoir Dogs - Wilde HundeReservoir Dogs - Wilde HundeReservoir Dogs - Wilde HundeReservoir Dogs - Wilde Hunde
# Eine Frage der EhreEine Frage der EhreEine Frage der EhreEine Frage der Ehre
# ErbarmungslosErbarmungslosErbarmungslosErbarmungslos
# JFK: Tatort DallasJFK: Tatort DallasJFK: Tatort DallasJFK: Tatort Dallas
# Die Muppets WeihnachtsgeschichteDie Muppets WeihnachtsgeschichteDie Muppets WeihnachtsgeschichteDie Muppets Weihnachtsgeschichte
# MiseryMiseryMiseryMisery
# Die Schöne und das BiestDie Schöne und das BiestDie Schöne und das BiestDie Schöne und das Biest
# AladdinAladdinAladdinAladdin
# Grüne TomatenGrüne TomatenGrüne TomatenGrüne Tomaten
# Thelma & LouiseThelma & LouiseThelma & LouiseThelma & Louise
# König der FischerKönig der FischerKönig der FischerKönig der Fischer
# Jacob's Ladder - In der Gewalt des JenseitsJacob's Ladder - In der Gewalt des JenseitsJacob's Ladder - In der Gewalt des JenseitsJacob's Ladder - In der Gewalt des Jenseits
# Armee der FinsternisArmee der FinsternisArmee der FinsternisArmee der Finsternis
# Miller's CrossingMiller's CrossingMiller's CrossingMiller's Crossing
# Ein Engel an meiner TafelEin Engel an meiner TafelEin Engel an meiner TafelEin Engel an meiner Tafel
# Zeit des ErwachensZeit des ErwachensZeit des ErwachensZeit des Erwachens
# Glengarry Glen RossGlengarry Glen RossGlengarry Glen RossGlengarry Glen Ross
# Barton FinkBarton FinkBarton FinkBarton Fink
# Malcolm XMalcolm XMalcolm XMalcolm X
# Chaplin - Das Leben der unsterblichen FilmlegendeChaplin - Das Leben der unsterblichen FilmlegendeChaplin - Das Leben der unsterblichen FilmlegendeChaplin - Das Leben der unsterblichen Filmlegende
# Die CommitmentsDie CommitmentsDie CommitmentsDie Commitments
# BraindeadBraindeadBraindeadBraindead
# The PlayerThe PlayerThe PlayerThe Player
# Von Mäusen und MenschenVon Mäusen und MenschenVon Mäusen und MenschenVon Mäusen und Menschen
# Die zwei Leben der VeronikaDie zwei Leben der VeronikaDie zwei Leben der VeronikaDie zwei Leben der Veronika
# Night on EarthNight on EarthNight on EarthNight on Earth
# DelicatessenDelicatessenDelicatessenDelicatessen
# Porco RossoPorco RossoPorco RossoPorco Rosso
# The Five HeartbeatsThe Five HeartbeatsThe Five HeartbeatsThe Five Heartbeats
# Die schöne QuerulantinDie schöne QuerulantinDie schöne QuerulantinDie schöne Querulantin
# Mann beißt HundMann beißt HundMann beißt HundMann beißt Hund
# Days of Being WildDays of Being WildDays of Being WildDays of Being Wild
# Ein Sommer zum VerliebenEin Sommer zum VerliebenEin Sommer zum VerliebenEin Sommer zum Verlieben
# Tränen der ErinnerungTränen der ErinnerungTränen der ErinnerungTränen der Erinnerung
# Rote LaterneRote LaterneRote LaterneRote Laterne
# Akira Kurosawa's TräumeAkira Kurosawa's TräumeAkira Kurosawa's TräumeAkira Kurosawa's Träume
# Hard BoiledHard BoiledHard BoiledHard Boiled
# []

# %%
# Paste the Selector from the first movie title copied from Chrome Dev Tools
#soup.select("#main > div > div.lister.list.detail.sub-list > div > div:nth-child(1) > div.lister-item-content ")

# Trim the selection: now it grabs all the titles
soup.select("div.lister-item-content > p:nth-child(4)")
# Out:
# [<p class="text-muted">
#      An eight-year-old troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation.</p>,
#  <p class="text-muted">
#      The story of <a href="/name/nm1453737">Henry Hill</a> and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.</p>,
#  <p class="text-muted">
#      Follows Michael Corleone, now in his 60s, as he seeks to free his family from crime and find a suitable successor to his empire.</p>,
#  <p class="text-muted">
#      A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.</p>,
#  <p class="text-muted">
#      When a man goes for virtual vacation memories of the planet Mars, an unexpected and harrowing series of events forces him to go to the planet for real - or is he?</p>,
#  <p class="text-muted">
#      Two New Yorkers accused of murder in rural Alabama while on their way back to college call in the help of one of their cousins, a loudmouth lawyer with no trial experience.</p>,
#  <p class="text-muted">
#      Follows the lives of three young males living in the Crenshaw ghetto of Los Angeles, dissecting questions of race, relationships, violence, and future prospects.</p>,
#  <p class="text-muted">
#      A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her teenage son, John Connor, from a more advanced and powerful cyborg.</p>,
#  <p class="text-muted">
#      A prep school student needing money agrees to "babysit" a blind man, but the job is not at all what he anticipated.</p>,
#  <p class="text-muted">
#      Three trappers protect the daughters of a British Colonel in the midst of the French and Indian War.</p>,
#  <p class="text-muted">
#      An artificial man, who was incompletely constructed and has scissors for hands, leads a solitary life. Then one day, a suburban lady meets him and introduces him to her world.</p>,
#  <p class="text-muted">
#      In November 1984, the Soviet Union's best submarine Captain in their newest sub violates orders and heads for the U.S. Is he trying to defect or to start a war?</p>,
#  <p class="text-muted">
#      Lieutenant John Dunbar, assigned to a remote western Civil War outpost, befriends wolves and Indians, making him an intolerable aberration in the military.</p>,
#  <p class="text-muted">
#      When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.</p>,
#  <p class="text-muted">
#      Military lawyer Lieutenant Daniel Kaffee defends Marines accused of murder. They contend they were acting under orders.</p>,
#  <p class="text-muted">
#      Retired Old West gunslinger William Munny reluctantly takes on one last job, with the help of his old partner Ned Logan and a young man, The "Schofield Kid."</p>,
#  <p class="text-muted">
#      New Orleans District Attorney <a href="/name/nm0308426">Jim Garrison</a> discovers there's more to the Kennedy assassination than the official story.</p>,
#  <p class="text-muted">
#      The Muppet characters tell their version of the classic tale of an old and bitter miser's redemption on Christmas Eve.</p>,
#  <p class="text-muted">
#      After a famous author is rescued from a car crash by a fan of his novels, he comes to realize that the care he is receiving is only the beginning of a nightmare of captivity and abuse.</p>,
#  <p class="text-muted">
#      A prince cursed to spend his days as a hideous monster sets out to regain his humanity by earning a young woman's love.</p>,
#  <p class="text-muted">
#      A kindhearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true.</p>,
#  <p class="text-muted">
#      A housewife who is unhappy with her life befriends an old lady in a nursing home and is enthralled by the tales she tells of people she used to know.</p>,
#  <p class="text-muted">
#      Two best friends set out on an adventure, but it soon turns around to a terrifying escape from being hunted by the police, as these two girls escape for the crimes they committed.</p>,
#  <p class="text-muted">
#      A former radio DJ, suicidally despondent because of a terrible mistake he made, finds redemption in helping a deranged homeless man who was an unwitting victim of that mistake.</p>,
#  <p class="text-muted">
#      Mourning his dead child, a haunted Vietnam War veteran attempts to uncover his past while suffering from a severe case of dissociation. To do so, he must decipher reality and life from his own dreams, delusions, and perceptions of death.</p>,
#  <p class="text-muted">
#      A sardonic hardware store clerk is accidentally transported to 1300 A.D., where he must retrieve the Necronomicon and battle an army of the dead so he can return home.</p>,
#  <p class="text-muted">
#      Tom Reagan, an advisor to a Prohibition-era crime boss, tries to keep the peace between warring mobs but gets caught in divided loyalties.</p>,
#  <p class="text-muted">
#      Janet Frame was a brilliant child who, as a teen, was misdiagnosed with schizophrenia. Explore Janet's discovery of the world and her life in Europe as her books are published to acclaim.</p>,
#  <p class="text-muted">
#      The victims of an encephalitis epidemic many years ago have been catatonic ever since, but now a new drug offers the prospect of reviving them.</p>,
#  <p class="text-muted">
#      An examination of the machinations behind the scenes at a real estate office.</p>,
#  <p class="text-muted">
#      A renowned New York playwright is enticed to California to write for the movies and discovers the hellish truth of Hollywood.</p>,
#  <p class="text-muted">
#      Biographical epic of the controversial and influential Black Nationalist leader, from his early life and career as a small-time gangster, to his ministry as a member of the Nation of Islam.</p>,
#  <p class="text-muted">
#      A film about the troubled and controversial life of the master comedy filmmaker <a href="/name/nm0000122">Charles Chaplin</a>.</p>,
#  <p class="text-muted">
#      Jimmy Rabbitte, an unemployed Dublin boy, decides to put together a soul band made up entirely of the Irish working class.</p>,
#  <p class="text-muted">
#      A young man's mother is bitten by a Sumatran rat-monkey. She gets sick and dies, at which time she comes back to life, killing and eating dogs, nurses, friends, and neighbors.</p>,
#  <p class="text-muted">
#      A Hollywood studio executive is being sent death threats by a writer whose script he rejected, but which one?</p>,
#  <p class="text-muted">
#      A nomadic farm worker looks after his dimwitted, gentle-giant friend during the Great Depression.</p>,
#  <p class="text-muted">
#      Two parallel stories about two identical women; one living in Poland, the other in France. They don't know each other, but their lives are nevertheless profoundly connected.</p>,
#  <p class="text-muted">
#      An anthology of 5 different cab drivers in 5 American and European cities and their remarkable fares on the same eventful night.</p>,
#  <p class="text-muted">
#      Post-apocalyptic surrealist black comedy about the landlord of an apartment building who occasionally prepares a delicacy for his odd tenants.</p>,
#  <p class="text-muted">
#      In 1930s Italy, a veteran World War I pilot is cursed to look like an anthropomorphic pig.</p>,
#  <p class="text-muted">
#      The story of the rise and fall of an African American vocal group.</p>,
#  <p class="text-muted">
#      The former famous painter Frenhofer revisits an abandoned project using the girlfriend of a young visiting artist. Questions about truth, life, and artistic limits are explored.</p>,
#  <p class="text-muted">
#      A film crew follows a ruthless thief and heartless killer as he goes about his daily routine. But complications set in when the film crew lose their objectivity and begin lending a hand.</p>,
#  <p class="text-muted">
#      A man tries to find out who his real mother is after the woman who raised him tells him the truth.</p>,
#  <p class="text-muted">
#      Based on a true story, primarily on a conflict between two youth gangs, a 14-year-old boy's girlfriend conflicts with the head of one gang for an unclear reason, until finally the conflict comes to a violent climax.</p>,
#  <p class="text-muted">
#      A twenty-seven-year-old office worker travels to the countryside while reminiscing about her childhood in Tokyo.</p>,
#  <p class="text-muted">
#      A young woman becomes the fourth wife of a wealthy lord, and must learn to live with the strict rules and tensions within the household.</p>,
#  <p class="text-muted">
#      A collection of tales based upon the actual dreams of director Akira Kurosawa.</p>,
#  <p class="text-muted">
#      A tough-as-nails cop teams up with an undercover agent to shut down a sinister mobster and his crew.</p>]

# %% [markdown]
# One of the ugliest things about the code above is that the HTML element containing the synopsis does not have any combination of tag and attribute that makes it unique. We've had to use select("p:nth-child(4)") and simply grab the 4th <p> element. Not very elegant... potentially will break... but, for now, it works.
#
# We have noticed how both the title and the synopsis are children of div.lister-item-content. That will make our looping task a bit simpler.
#
# There are many approaches to do this. The one we'll follow is:
#
# Loop through the pages we collected, parse them ("create the soup") and store the parsed pages in a list.
# For each parsed page, select the "blocks of HTML elements" that contain all the information of each movie (the title, the synopsis and other stuff).
# For each one of the "blocks" we collected in the previous step:
# Get the movie titles and store them in a list
# Get the synopsis and store them in a list
# Here's the code that does that:

# %%
pages_parsed = []
titles = []
synopsis = []

for i in range(len(pages)):
    # parse all pages
    pages_parsed.append(BeautifulSoup(pages[i].content, "html.parser"))
    # select only the info about the movies
    movies_html = pages_parsed[i].select("div.lister-item-content")
    # for movie, store titles and reviews into lists
    for j in range(len(movies_html)):
        titles.append(movies_html[j].select("h3 > a")[0].get_text())
        synopsis.append(movies_html[j].select("p:nth-child(4)")[0].get_text().strip())

# %%
content = []

for i in iterations:
    # assemble the url:
    start_at= str(i)
    url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=" + start_at + "&ref_=adv_nxt"

    # download html with a get request:
    response = requests.get(url)

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))

    soup = BeautifulSoup(response.content, "html.parser")
    content.append(soup)

    # respectful nap:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    time.sleep(wait_time)
# Out:
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 2 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 3 second/s.

# %%
film_title = []
for page in content:
    film_title.extend(page.select("div.lister-item-content > h3 > a"))

# %%
#content[1].select("div.lister-item-content > h3 > a")

# %%
len(film_title)
# Out:
# 631

# %%
long_list = []
for film in film_title:
    #print(film.text)
    long_list.append(film.text)

# %%
#long_list

# %%
synopsis = []
for page in content:
    synopsis.extend(page.select("p:nth-child(4)"))

# %%
content[0].select("p:nth-child(4)")

#select("p:nth-child(4)").get_text().strip())
# Out:
# [<p class="text-muted">
#      An eight-year-old troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation.</p>,
#  <p class="text-muted">
#      The story of <a href="/name/nm1453737">Henry Hill</a> and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.</p>,
#  <p class="text-muted">
#      Follows Michael Corleone, now in his 60s, as he seeks to free his family from crime and find a suitable successor to his empire.</p>,
#  <p class="text-muted">
#      A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.</p>,
#  <p class="text-muted">
#      When a man goes for virtual vacation memories of the planet Mars, an unexpected and harrowing series of events forces him to go to the planet for real - or is he?</p>,
#  <p class="text-muted">
#      Two New Yorkers accused of murder in rural Alabama while on their way back to college call in the help of one of their cousins, a loudmouth lawyer with no trial experience.</p>,
#  <p class="text-muted">
#      Follows the lives of three young males living in the Crenshaw ghetto of Los Angeles, dissecting questions of race, relationships, violence, and future prospects.</p>,
#  <p class="text-muted">
#      A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her teenage son, John Connor, from a more advanced and powerful cyborg.</p>,
#  <p class="text-muted">
#      A prep school student needing money agrees to "babysit" a blind man, but the job is not at all what he anticipated.</p>,
#  <p class="text-muted">
#      Three trappers protect the daughters of a British Colonel in the midst of the French and Indian War.</p>,
#  <p class="text-muted">
#      An artificial man, who was incompletely constructed and has scissors for hands, leads a solitary life. Then one day, a suburban lady meets him and introduces him to her world.</p>,
#  <p class="text-muted">
#      In November 1984, the Soviet Union's best submarine Captain in their newest sub violates orders and heads for the U.S. Is he trying to defect or to start a war?</p>,
#  <p class="text-muted">
#      Lieutenant John Dunbar, assigned to a remote western Civil War outpost, befriends wolves and Indians, making him an intolerable aberration in the military.</p>,
#  <p class="text-muted">
#      When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.</p>,
#  <p class="text-muted">
#      Military lawyer Lieutenant Daniel Kaffee defends Marines accused of murder. They contend they were acting under orders.</p>,
#  <p class="text-muted">
#      Retired Old West gunslinger William Munny reluctantly takes on one last job, with the help of his old partner Ned Logan and a young man, The "Schofield Kid."</p>,
#  <p class="text-muted">
#      New Orleans District Attorney <a href="/name/nm0308426">Jim Garrison</a> discovers there's more to the Kennedy assassination than the official story.</p>,
#  <p class="text-muted">
#      The Muppet characters tell their version of the classic tale of an old and bitter miser's redemption on Christmas Eve.</p>,
#  <p class="text-muted">
#      After a famous author is rescued from a car crash by a fan of his novels, he comes to realize that the care he is receiving is only the beginning of a nightmare of captivity and abuse.</p>,
#  <p class="text-muted">
#      A prince cursed to spend his days as a hideous monster sets out to regain his humanity by earning a young woman's love.</p>,
#  <p class="text-muted">
#      A kindhearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true.</p>,
#  <p class="text-muted">
#      A housewife who is unhappy with her life befriends an old lady in a nursing home and is enthralled by the tales she tells of people she used to know.</p>,
#  <p class="text-muted">
#      Two best friends set out on an adventure, but it soon turns around to a terrifying escape from being hunted by the police, as these two girls escape for the crimes they committed.</p>,
#  <p class="text-muted">
#      A former radio DJ, suicidally despondent because of a terrible mistake he made, finds redemption in helping a deranged homeless man who was an unwitting victim of that mistake.</p>,
#  <p class="text-muted">
#      Mourning his dead child, a haunted Vietnam War veteran attempts to uncover his past while suffering from a severe case of dissociation. To do so, he must decipher reality and life from his own dreams, delusions, and perceptions of death.</p>,
#  <p class="text-muted">
#      A sardonic hardware store clerk is accidentally transported to 1300 A.D., where he must retrieve the Necronomicon and battle an army of the dead so he can return home.</p>,
#  <p class="text-muted">
#      Tom Reagan, an advisor to a Prohibition-era crime boss, tries to keep the peace between warring mobs but gets caught in divided loyalties.</p>,
#  <p class="text-muted">
#      Janet Frame was a brilliant child who, as a teen, was misdiagnosed with schizophrenia. Explore Janet's discovery of the world and her life in Europe as her books are published to acclaim.</p>,
#  <p class="text-muted">
#      The victims of an encephalitis epidemic many years ago have been catatonic ever since, but now a new drug offers the prospect of reviving them.</p>,
#  <p class="text-muted">
#      An examination of the machinations behind the scenes at a real estate office.</p>,
#  <p class="text-muted">
#      A renowned New York playwright is enticed to California to write for the movies and discovers the hellish truth of Hollywood.</p>,
#  <p class="text-muted">
#      Biographical epic of the controversial and influential Black Nationalist leader, from his early life and career as a small-time gangster, to his ministry as a member of the Nation of Islam.</p>,
#  <p class="text-muted">
#      A film about the troubled and controversial life of the master comedy filmmaker <a href="/name/nm0000122">Charles Chaplin</a>.</p>,
#  <p class="text-muted">
#      Jimmy Rabbitte, an unemployed Dublin boy, decides to put together a soul band made up entirely of the Irish working class.</p>,
#  <p class="text-muted">
#      A young man's mother is bitten by a Sumatran rat-monkey. She gets sick and dies, at which time she comes back to life, killing and eating dogs, nurses, friends, and neighbors.</p>,
#  <p class="text-muted">
#      A Hollywood studio executive is being sent death threats by a writer whose script he rejected, but which one?</p>,
#  <p class="text-muted">
#      A nomadic farm worker looks after his dimwitted, gentle-giant friend during the Great Depression.</p>,
#  <p class="text-muted">
#      Two parallel stories about two identical women; one living in Poland, the other in France. They don't know each other, but their lives are nevertheless profoundly connected.</p>,
#  <p class="text-muted">
#      An anthology of 5 different cab drivers in 5 American and European cities and their remarkable fares on the same eventful night.</p>,
#  <p class="text-muted">
#      Post-apocalyptic surrealist black comedy about the landlord of an apartment building who occasionally prepares a delicacy for his odd tenants.</p>,
#  <p class="text-muted">
#      In 1930s Italy, a veteran World War I pilot is cursed to look like an anthropomorphic pig.</p>,
#  <p class="text-muted">
#      The story of the rise and fall of an African American vocal group.</p>,
#  <p class="text-muted">
#      The former famous painter Frenhofer revisits an abandoned project using the girlfriend of a young visiting artist. Questions about truth, life, and artistic limits are explored.</p>,
#  <p class="text-muted">
#      A film crew follows a ruthless thief and heartless killer as he goes about his daily routine. But complications set in when the film crew lose their objectivity and begin lending a hand.</p>,
#  <p class="text-muted">
#      A man tries to find out who his real mother is after the woman who raised him tells him the truth.</p>,
#  <p class="text-muted">
#      Based on a true story, primarily on a conflict between two youth gangs, a 14-year-old boy's girlfriend conflicts with the head of one gang for an unclear reason, until finally the conflict comes to a violent climax.</p>,
#  <p class="text-muted">
#      A twenty-seven-year-old office worker travels to the countryside while reminiscing about her childhood in Tokyo.</p>,
#  <p class="text-muted">
#      A young woman becomes the fourth wife of a wealthy lord, and must learn to live with the strict rules and tensions within the household.</p>,
#  <p class="text-muted">
#      A collection of tales based upon the actual dreams of director Akira Kurosawa.</p>,
#  <p class="text-muted">
#      A tough-as-nails cop teams up with an undercover agent to shut down a sinister mobster and his crew.</p>]

# %%
len(synopsis)
# Out:
# 631

# %%
synopsis_list = []
for thing in synopsis:
    synopsis_list.append((thing.text).strip('\n '))

# %%
import pandas as pd

all = pd.DataFrame()

# %%
all['FiltTitle'] = long_list

# %%
all['Synopsis'] = synopsis_list

# %%
all.head(25)
# Out:
#                                       FiltTitle  \
# 0                        Kevin - Allein zu Haus
# 1     GoodFellas - Drei Jahrzehnte in der Mafia
# 2                                    Der Pate 3
# 3                      Das Schweigen der Lämmer
# 4          Total Recall - Die totale Erinnerung
# 5                            Mein Vetter Winnie
# 6            Boyz n the Hood - Jungs im Viertel
# 7              Terminator 2: Tag der Abrechnung
# 8                           Der Duft der Frauen
# 9                          Der letzte Mohikaner
# 10                 Edward mit den Scherenhänden
# 11                       Jagd auf Roter Oktober
# 12                       Der mit dem Wolf tanzt
# 13                 Reservoir Dogs - Wilde Hunde
# 14                          Eine Frage der Ehre
# 15                                Erbarmungslos
# 16                           JFK: Tatort Dallas
# 17             Die Muppets Weihnachtsgeschichte
# 18                                       Misery
# 19                     Die Schöne und das Biest
# 20                                      Aladdin
# 21                                Grüne Tomaten
# 22                              Thelma & Louise
# 23                            König der Fischer
# 24  Jacob's Ladder - In der Gewalt des Jenseits
#
#                                              Synopsis
# 0   An eight-year-old troublemaker must protect hi...
# 1   The story of Henry Hill and his life in the mo...
# 2   Follows Michael Corleone, now in his 60s, as h...
# 3   A young F.B.I. cadet must receive the help of ...
# 4   When a man goes for virtual vacation memories ...
# 5   Two New Yorkers accused of murder in rural Ala...
# 6   Follows the lives of three young males living ...
# 7   A cyborg, identical to the one who failed to k...
# 8   A prep school student needing money agrees to ...
# 9   Three trappers protect the daughters of a Brit...
# 10  An artificial man, who was incompletely constr...
# 11  In November 1984, the Soviet Union's best subm...
# 12  Lieutenant John Dunbar, assigned to a remote w...
# 13  When a simple jewelry heist goes horribly wron...
# 14  Military lawyer Lieutenant Daniel Kaffee defen...
# 15  Retired Old West gunslinger William Munny relu...
# 16  New Orleans District Attorney Jim Garrison dis...
# 17  The Muppet characters tell their version of th...
# 18  After a famous author is rescued from a car cr...
# 19  A prince cursed to spend his days as a hideous...
# 20  A kindhearted street urchin and a power-hungry...
# 21  A housewife who is unhappy with her life befri...
# 22  Two best friends set out on an adventure, but ...
# 23  A former radio DJ, suicidally despondent becau...
# 24  Mourning his dead child, a haunted Vietnam War...

# %%
all.tail(25)
# Out:
#                             FiltTitle  \
# 606                      Razluchnitsa
# 607                  Igra na milliony
# 608              Golmaal Radhakrishna
# 609                     État critique
# 610                          Feldberg
# 611                    Curious George
# 612                          Haladhar
# 613  Märkische Heide, märkischer Sand
# 614                              Lina
# 615  What Ignites Me, Extinguishes Me
# 616                          Phuk pui
# 617                       Katastroika
# 618         Passage Through: A Ritual
# 619           Jeta në duart e tjetrit
# 620                       In het rood
# 621                        Gunda Gang
# 622                     Herakeya Kuri
# 623                      Zaoyu jiqing
# 624     Barzo, akuratno, okonchatelno
# 625                   Ranga Mera Naam
# 626          Një djalë edhe një vajzë
# 627         Innebunesc si-mi pare rau
# 628  Linda McCartney: Behind the Lens
# 629                Sobachye shchastye
# 630              Het Phoenix mysterie
#
#                                               Synopsis
# 606                                         Add a Plot
# 607  Two gangs of professional racketeers are engag...
# 608  Radhakrishna, a player, dates two women simult...
# 609  Long métrage documentaire sur les critiques cu...
# 610                                         Add a Plot
# 611                                         Add a Plot
# 612                                         Add a Plot
# 613                                         Add a Plot
# 614                                         Add a Plot
# 615                                         Add a Plot
# 616  Wow, a young boy living with his family in a b...
# 617                                         Add a Plot
# 618                                         Add a Plot
# 619                                         Add a Plot
# 620                                         Add a Plot
# 621                                         Add a Plot
# 622  Watch the full movie, Harakeya Kuri online, on...
# 623                                         Add a Plot
# 624                                         Add a Plot
# 625                                         Add a Plot
# 626  Artan a teenager in high school starts hanging...
# 627                                         Add a Plot
# 628                                         Add a Plot
# 629  Dog's happiness is at it's highest, when this ...
# 630                                         Add a Plot
